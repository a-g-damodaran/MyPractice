# %%
import matplotlib.pyplot as plt

year = [2015,2016,2017,2018,2019]
sales = [4356,4432,3333,2322,4323]
profit = [453,223,344,433,233]

# %%
plt.plot(year,sales, 'red')
plt.plot(year, profit, 'blue')
plt.title('Year vs Profit and Sales analysis')
plt.xlabel('Years')
plt.ylabel('Profit and Sales')
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(year, sales, 'red')
plt.xlabel('Years')
plt.ylabel('Sales')
plt.title('Sales by Year')
# Out:
# Text(0.5, 1.0, 'Sales by Year')

# %%
plt.subplot(2,2,2)
plt.plot(year, profit, 'blue')
plt.xlabel('Years')
plt.ylabel('Profit')
plt.title('Profit by Year')
plt.tight_layout()

# %%
plt.plot(year, sales, 'red')
plt.xlabel('Years')
plt.ylabel('Sales')
plt.title('Sales by Year')
plt.ylim((2500,3500))
#plt.xlim((2016,2018))
# Out:
# (2500.0, 3500.0)

# %%
import pandas as pd

car = pd.read_excel('Car.xlsx')

for group, data in car.groupby('Manufacturer'):
    print(group,data['4-year resale value'].mean())

plt.figure(figsize=(10,7))
for group, data in car.groupby('Manufacturer'):
    plt.barh(group,data['4-year resale value'].mean())
# Out:
# Acura 21.04625
# Audi 28.27
# BMW 27.6243250688705
# Buick 14.94125
# Cadillac 22.3295950413223
# Chevrolet 13.768663911845724
# Chrysler 15.406139315230215
# Dodge 16.961634109691953
# Ford 13.424815927873773
# Honda 15.556999999999999
# Hyundai 7.531666666666666
# Infiniti 19.69
# Jaguar 18.0729752066115
# Jeep 15.353333333333333
# Lexus 25.607320936639084
# Lincoln 20.107658402203832
# Mercedes-Benz 29.64887511478417
# Mercury 13.969999999999999
# Mitsubishi 14.262142857142857
# Nissan 14.886564344746144
# Oldsmobile 17.073491735537168
# Plymouth 11.911993801652875
# Pontiac 14.53216253443525
# Porsche 56.475
# Saab 18.0729752066115
# Saturn 13.345190082644601
# Subaru 18.0729752066115
# Toyota 16.814775022956834
# Volkswagen 14.966329201101916
# Volvo 18.0729752066115

# %%
car['Vehicle type'].unique()

vt_dict = dict()
for i in set(car['Vehicle type']):
    vt_dict[i] = car[car['Vehicle type']==i].Manufacturer.count()
vt_dict
plt.bar(vt_dict.keys(), vt_dict.values())
# Out:
# <BarContainer object of 2 artists>

# %%
plt.figure(figsize=(10,8))
for group, data in car.groupby('Manufacturer'):
    plt.barh(group, data['4-year resale value'].mean())
    plt.barh(group, data['Price in thousands'].mean(), left = data['4-year resale value'].mean())

plt.hist(car.Horsepower, bins=10)
plt.show()

plt.hist(car['Fuel efficiency'], bins=10)
plt.show()

# %%
#pie 
vt_dict = dict()
for i in set(car['Vehicle type']):
    vt_dict[i] = car[car['Vehicle type']==i].Manufacturer.count()
vt_dict
plt.pie( vt_dict.values(),labels = vt_dict.keys())
plt.show()

# %%
#Scatter
plt.scatter(car['Fuel capacity'], car['Fuel efficiency'])

# %%
import seaborn as sns
sns.distplot(car['Fuel efficiency'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fuel efficiency', ylabel='Density'>

# %%
car.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     2
# Engine size            1
# Horsepower             0
# Wheelbase              1
# Width                  1
# Length                 1
# Curb weight            2
# Fuel capacity          1
# Fuel efficiency        3
# Latest Launch          0
# dtype: int64

# %%
sns.distplot(car['Sales in thousands'], kde=False)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales in thousands'>

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    float64
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   155 non-null    float64
#  6   Engine size          156 non-null    float64
#  7   Horsepower           157 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb weight          155 non-null    float64
#  12  Fuel capacity        156 non-null    float64
#  13  Fuel efficiency      154 non-null    float64
#  14  Latest Launch        157 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), object(3)
# memory usage: 18.5+ KB

# %%
sns.regplot(data = car, y = 'Fuel efficiency', x = 'Fuel capacity', fit_reg=False)
# Out:
# <AxesSubplot:xlabel='Fuel capacity', ylabel='Fuel efficiency'>

# %%
sns.regplot(data = car, y = 'Fuel efficiency', x = 'Fuel capacity', fit_reg=True)
# Out:
# <AxesSubplot:xlabel='Fuel capacity', ylabel='Fuel efficiency'>

# %%
sns.lmplot(data = car , y = 'Fuel efficiency', x = 'Fuel capacity', fit_reg=False, hue='Vehicle type')

# %%
sns.lmplot(data = car , y = 'Fuel efficiency', x = 'Fuel capacity', fit_reg=False, col='Vehicle type')

# %%
sns.jointplot(data = car, x = 'Fuel capacity', y = 'Fuel efficiency', kind='kde' )

# %%
sns.countplot(data =car, x = 'Vehicle type')
# Out:
# <AxesSubplot:xlabel='Vehicle type', ylabel='count'>

# %%
sns.barplot(y = '4-year resale value', x = 'Vehicle type', data = car)
# Out:
# <AxesSubplot:xlabel='Vehicle type', ylabel='4-year resale value'>

# %%
sns.stripplot(y = '4-year resale value', x = 'Vehicle type', data = car)
# Out:
# <AxesSubplot:xlabel='Vehicle type', ylabel='4-year resale value'>

# %%
sns.pairplot(car[['Horsepower', 'Fuel efficiency', 'Fuel capacity', 'Curb weight']])

# %%
sns.heatmap(car[['Horsepower', 'Curb weight', 'Fuel capacity', 'Fuel efficiency']].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
car[['Horsepower', 'Curb weight', 'Fuel capacity', 'Fuel efficiency']].corr()
# Out:
#                  Horsepower  Curb weight  Fuel capacity  Fuel efficiency
# Horsepower         1.000000     0.610131       0.499907        -0.611332
# Curb weight        0.610131     1.000000       0.863968        -0.818402
# Fuel capacity      0.499907     0.863968       1.000000        -0.801512
# Fuel efficiency   -0.611332    -0.818402      -0.801512         1.000000

# %%
#Box and Whiskers plot 
sns.boxplot(data = car, x = 'Vehicle type', y = 'Fuel capacity')
# Out:
# <AxesSubplot:xlabel='Vehicle type', ylabel='Fuel capacity'>

# %%
sns.violinplot(data = car, x = 'Vehicle type', y = 'Fuel capacity')
# Out:
# <AxesSubplot:xlabel='Vehicle type', ylabel='Fuel capacity'>

# %%
import matplotlib.pyplot as plt
print(plt.style.available)
plt.style.use('fivethirtyeight')
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
